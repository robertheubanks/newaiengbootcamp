# %% [markdown]
# <a href="https://colab.research.google.com/github/robertheubanks/newaiengbootcamp/blob/main/Eubanks_AIEngBootCamp_Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Let's install the libraries
# !pip install -U -q langchain langchain-openai langchain_core langchain-community langchainhub openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.5/807.5 kB 16.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.9/256.9 kB 33.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 59.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.4/227.4 kB 32.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.6/66.6 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 70.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 22.2 MB/s eta 0:00:00

# %%
### Let's also install RAGAS
# !pip install -qU ragas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 24.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.7 MB/s eta 0:00:00

# %%
### Let's load FAISS as our vector store and also the pdf loader that we will use to load the NVIDIA 10-k. we are also using Unstructured IOs Unstructured pdf loader
# !pip install -qU faiss_cpu pymupdf pandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 60.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 104.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 90.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 43.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 33.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.22.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.1 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.2.1 which is incompatible.

# %%
### Now, let's load OpenAI so that we can use it
import os
import openai
from getpass import getpass

openai.api_key = getpass("Please provide your OpenAI Key: ")
os.environ["OPENAI_API_KEY"] = openai.api_key
# Out:
# Please provide your OpenAI Key: ··········

# %%
### Let's load the NVIDIA 10-k
from langchain_community.document_loaders import PyMuPDFLoader

# Construct the path to the PDF
pdf_path = "https://d18rn0p25nwr6d.cloudfront.net/CIK-0001045810/1cbe8fe7-e08a-46e3-8dcc-b429fc06c1a4.pdf"

# Initialize the PyMuPDFLoader with the correct path
loader = PyMuPDFLoader(pdf_path)

# Load the PDF into documents
documents = loader.load()

# %%
### We will now split the documents into chunks. We will start with a chunk size of 700 with an overlap of 50. We can play around with these to see if there is any impact on output quality.
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 700,
    chunk_overlap = 50
)

documents = text_splitter.split_documents(documents)

# %%
### Let's confirm the document has been split up
len(documents)
# Out:
# 624

# %%
### Let's load OpenAI's text embedding 3 small
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small"
)

# %%
### Let's create a vector store using Meta's FAISS
from langchain_community.vectorstores import FAISS

vector_store = FAISS.from_documents(documents, embeddings)

# %%
### Let's create the retriever
retriever = vector_store.as_retriever()

# %%
### Now we need to create a prompt template.
from langchain.prompts import ChatPromptTemplate

template = """Answer the question based only on the following context. If you cannot answer the question with the context, please respond with 'I don't know':

Context:
{context}

Question:
{question}
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
### Now we will create a basic Q&A RAG chain
from operator import itemgetter

from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

primary_qa_llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

retrieval_augmented_qa_chain = (
    # INVOKE CHAIN WITH: {"question" : "<<SOME USER QUESTION>>"}
    # "question" : populated by getting the value of the "question" key
    # "context"  : populated by getting the value of the "question" key and chaining it into the base_retriever
    {"context": itemgetter("question") | retriever, "question": itemgetter("question")}
    # "context"  : is assigned to a RunnablePassthrough object (will not be called or considered in the next step)
    #              by getting the value of the "context" key from the previous step
    | RunnablePassthrough.assign(context=itemgetter("context"))
    # "response" : the "context" and "question" values are used to format our prompt object and then piped
    #              into the LLM and stored in a key called "response"
    # "context"  : populated by getting the value of the "context" key from the previous step
    | {"response": prompt | primary_qa_llm, "context": itemgetter("context")}
)

# %%
### Here is the first question
question = "Who is the E-VP, Operations - and how old are they?"

result = retrieval_augmented_qa_chain.invoke({"question" : question})

print(result["response"].content)
# Out:
# Debora Shoquist is the Executive Vice President, Operations, and she is 69 years old.

# %%
### Here is the second question
question = "What is the gross carrying amount of Total Amortizable Intangible Assets for Jan 29, 2023?"

result = retrieval_augmented_qa_chain.invoke({"question" : question})

print(result["response"].content)
# Out:
# $3,539

# %%
### Now we will do the RAGAS evaulation
### We need to generate a synthetic data test set
eval_documents = documents

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1500,
    chunk_overlap = 400
)

eval_documents = text_splitter.split_documents(eval_documents)

# %%
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context

generator = TestsetGenerator.with_openai()

testset = generator.generate_with_langchain_docs(documents, test_size=10, distributions={simple: 0.25, reasoning: 0.25, multi_context: 0.5})
# Out:
# embedding nodes:   0%|          | 0/1248 [00:00<?, ?it/s]
# WARNING:ragas.testset.docstore:Filename and doc_id are the same for all nodes.
# Generating:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
### Now that we have QC pairs, ground truth, we can start doing the evaluation
test_df = testset.to_pandas()

# %%
test_df
# Out:
#                                             question  \
# 0  What procedures were performed to assess the r...
# 1  What is the potential impact of tax authoritie...
# 2  "What method do we use to estimate product ret...
# 3  What are the consequences of tax audits and ch...
# 4  What factor affects the tax rate in business c...
# 5  "What factors can affect our assessments of de...
# 6  What is the role of auditor judgment in evalua...
# 7  How could export controls on networking produc...
# 8  How are impairments for non-marketable equity ...
# 9  How has NVIDIA attracted top global talent giv...
#
#                                             contexts  \
# 0  [assurance about whether the consolidated fina...
# 1  [determining our worldwide provision for incom...
# 2  [For products sold with a right of return, we ...
# 3  [determining our worldwide provision for incom...
# 4  [adjustments to income taxes upon finalization...
# 5  [Our calculation of deferred tax assets and li...
# 6  [provisions for excess or obsolete inventories...
# 7  [controls to restrict additional gaming produc...
# 8  [based on quantitative and qualitative factors...
# 9  [relating to human capital management.\nTo be ...
#
#                                         ground_truth evolution_type  \
# 0  performing procedures to assess the risks of m...         simple
# 1  Any adverse outcome could increase our worldwi...         simple
# 2  We may determine that additional sales return ...      reasoning
# 3  Any adverse outcome of tax audits could increa...      reasoning
# 4               accounting for business combinations  multi_context
# 5  Our estimates of deferred tax assets and liabi...  multi_context
# 6  The role of auditor judgment in evaluating man...  multi_context
# 7  Export controls on networking products could d...  multi_context
# 8  Impairments for non-marketable equity securiti...  multi_context
# 9  NVIDIA has attracted top global talent through...      reasoning
#
#    episode_done
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True

# %%
test_questions = test_df["question"].values.tolist()
test_groundtruths = test_df["ground_truth"].values.tolist()

# %%
### Now we will generate some responses using our RAG pipeline based on teh questions we generated
answers = []
contexts = []

for question in test_questions:
  response = retrieval_augmented_qa_chain.invoke({"question" : question})
  answers.append(response["response"].content)
  contexts.append([context.page_content for context in response["context"]])

# %%
### We will use a dataset from Hugging Face for the RAG library
from datasets import Dataset

response_dataset = Dataset.from_dict({
    "question" : test_questions,
    "answer" : answers,
    "contexts" : contexts,
    "ground_truth" : test_groundtruths
})

# %%
### Now that we have the response dataset we can do the RAGAS evaluation
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    answer_correctness,
    context_recall,
    context_precision,
)

metrics = [
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    answer_correctness,
]

# %%
### Let's evaluate
results = evaluate(response_dataset, metrics)
# Out:
# Evaluating:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
results
# Out:
# {'faithfulness': 1.0000, 'answer_relevancy': 0.9422, 'context_recall': 1.0000, 'context_precision': 1.0000, 'answer_correctness': 0.7184}

# %%
results_df = results.to_pandas()
results_df
# Out:
#                                             question  \
# 0  What procedures were performed to assess the r...
# 1  What is the potential impact of tax authoritie...
# 2  "What method do we use to estimate product ret...
# 3  What are the consequences of tax audits and ch...
# 4  What factor affects the tax rate in business c...
# 5  "What factors can affect our assessments of de...
# 6  What is the role of auditor judgment in evalua...
# 7  How could export controls on networking produc...
# 8  How are impairments for non-marketable equity ...
# 9  How has NVIDIA attracted top global talent giv...
#
#                                               answer  \
# 0  The procedures performed to assess the risks o...
# 1  Tax authorities could potentially increase our...
# 2  If historical return rates are insufficient, a...
# 3  The consequences of tax audits and changes in ...
# 4  The impact of accounting for business combinat...
# 5  Changes in accounting standards or tax laws in...
# 6  The role of auditor judgment in evaluating man...
# 7  Export controls on networking products could d...
# 8  Impairments for non-marketable equity securiti...
# 9  NVIDIA has attracted top global talent through...
#
#                                             contexts  \
# 0  [assurance about whether the consolidated fina...
# 1  [consequences, including but not limited to, g...
# 2  [For products sold with a right of return, we ...
# 3  [determining our worldwide provision for incom...
# 4  [adjustments to income taxes upon finalization...
# 5  [Our calculation of deferred tax assets and li...
# 6  [provisions for excess or obsolete inventories...
# 7  [controls to restrict additional gaming produc...
# 8  [based on quantitative and qualitative factors...
# 9  [relating to human capital management.\nTo be ...
#
#                                         ground_truth  faithfulness  \
# 0  performing procedures to assess the risks of m...           1.0
# 1  Any adverse outcome could increase our worldwi...           1.0
# 2  We may determine that additional sales return ...           1.0
# 3  Any adverse outcome of tax audits could increa...           1.0
# 4               accounting for business combinations           1.0
# 5  Our estimates of deferred tax assets and liabi...           1.0
# 6  The role of auditor judgment in evaluating man...           1.0
# 7  Export controls on networking products could d...           1.0
# 8  Impairments for non-marketable equity securiti...           1.0
# 9  NVIDIA has attracted top global talent through...           1.0
#
#    answer_relevancy  context_recall  context_precision  answer_correctness
# 0          1.000000             1.0                1.0            0.729266
# 1          0.965224             1.0                1.0            0.881995
# 2          0.806109             1.0                1.0            0.734081
# 3          0.987270             1.0                1.0            0.690994
# 4          0.899454             1.0                1.0            0.720500
# 5          0.944890             1.0                1.0            0.662877
# 6          0.937822             1.0                1.0            0.458054
# 7          0.942952             1.0                1.0            0.694302
# 8          0.961154             1.0                1.0            0.611659
# 9          0.977023             1.0                1.0            1.000000
